# %% [markdown]
# ## Dogs v Cats resNet50

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# This file contains all the main external libs we'll use
from fastai.imports import *

from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

PATH = "data/dogscats/"
sz=299 # 此处大小299
arch=resnext50
bs= 16

# %%
tfms = tfms_from_model(arch, sz, aug_tfms=transforms_side_on, max_zoom=1.1)
data = ImageClassifierData.from_paths(PATH, tfms=tfms, bs=bs, num_workers=4)

# %% [markdown]
# 此处precompute的意思是：我们不必要每次都去计算卷积层输出，而是只计算最后的卷积输出

# %%
learn = ConvLearner.pretrained(arch, data, precompute=True)
# Out:
# 100%|██████████| 1438/1438 [03:20<00:00,  7.17it/s]
# 100%|██████████| 125/125 [00:12<00:00,  9.81it/s]

# %%
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 299, 299]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('trainable', False),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('trainable', False),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('Conv2d-13',
#               OrderedDict([('input_shape', [-1, 64, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-14',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-15',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-17',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-18',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-36',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-39',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-48',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-49',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-50',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-56',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-57',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-58',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-59',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-66',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-67',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 512)])),
#              ('ReLU-68',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-69',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-70',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-71',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-78',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-79',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('Conv2d-80',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-81',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-82',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-83',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-84',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-85',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-92',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-93',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-94',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-95',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-96',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-97',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-98',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-99',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-100',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-101',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-102',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-103',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-104',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-105',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-106',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-107',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-108',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-109',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-110',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-111',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-112',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-113',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-114',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-115',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-122',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-123',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1024)])),
#              ('ReLU-124',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-125',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-126',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-127',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-130',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-131',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-132',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-133',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-134',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-135',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('Conv2d-136',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-137',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-138',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-139',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-140',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-141',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-142',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-143',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-144',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-145',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-146',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-147',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-148',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-149',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-150',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-151',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-152',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2048)])),
#              ('ReLU-153',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-154',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-155',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', False),
#                            ('nb_params', 4096)])),
#              ('ReLU-156',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-157',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-158',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-159',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 4096, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-160',
#               OrderedDict([('input_shape', [-1, 4096, 1, 1]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-161',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('Dropout-162',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('Linear-163',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 2097664)])),
#              ('ReLU-164',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-165',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-166',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-167',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 2]),
#                            ('trainable', True),
#                            ('nb_params', 1026)])),
#              ('LogSoftmax-168',
#               OrderedDict([('input_shape', [-1, 2]),
#                            ('output_shape', [-1, 2]),
#                            ('nb_params', 0)]))])

# %%
learn
# Out:
# Sequential(
#   (0): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True)
#   (1): Dropout(p=0.25)
#   (2): Linear(in_features=4096, out_features=512)
#   (3): ReLU()
#   (4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True)
#   (5): Dropout(p=0.5)
#   (6): Linear(in_features=512, out_features=2)
#   (7): LogSoftmax()
# )

# %% [markdown]
# 我么可以看到只有最后的几层是可训练的，其他都是保持不变的，也就是之前说的 **只计算最后的卷积输出**

# %%
learn.fit(1e-2, 1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=1), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.077814   0.026055   0.9935
# [0.026055487, 0.9935]

# %%
# 设置 precompute=False 让数据增强起效果，即重新计算图像输入
learn.precompute=False

# %%
# learn.summary() # 卷积层还是不可训练的，但是会重新计算

# %%
learn.fit(1e-2, 2, cycle_len=1)
# Out:
# HBox(children=(IntProgress(value=0, description='Epoch', max=2), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.047221   0.025105   0.993
#     1      0.037409   0.02608    0.993
# [0.026080243, 0.993]

# %%
# 将所有层都设置为可训练
learn.unfreeze()

# %%
# 发现此时所有层都可训练了
learn.summary()
# Out:
# OrderedDict([('Conv2d-1',
#               OrderedDict([('input_shape', [-1, 3, 299, 299]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('trainable', True),
#                            ('nb_params', 9408)])),
#              ('BatchNorm2d-2',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('trainable', True),
#                            ('nb_params', 128)])),
#              ('ReLU-3',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 150, 150]),
#                            ('nb_params', 0)])),
#              ('MaxPool2d-4',
#               OrderedDict([('input_shape', [-1, 64, 150, 150]),
#                            ('output_shape', [-1, 64, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-5',
#               OrderedDict([('input_shape', [-1, 64, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('BatchNorm2d-6',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-7',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-8',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-9',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-10',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-11',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-12',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('Conv2d-13',
#               OrderedDict([('input_shape', [-1, 64, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 16384)])),
#              ('BatchNorm2d-14',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-15',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-16',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-17',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-18',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-19',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-20',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-21',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-22',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-23',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-24',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-25',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-26',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-27',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-28',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 4608)])),
#              ('BatchNorm2d-29',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 256)])),
#              ('ReLU-30',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 128, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-31',
#               OrderedDict([('input_shape', [-1, 128, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 32768)])),
#              ('BatchNorm2d-32',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-33',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-34',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 65536)])),
#              ('BatchNorm2d-35',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-36',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 75, 75]),
#                            ('nb_params', 0)])),
#              ('Conv2d-37',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-38',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-39',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-40',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-41',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Conv2d-42',
#               OrderedDict([('input_shape', [-1, 256, 75, 75]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-43',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-44',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-45',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-46',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-47',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-48',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-49',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-50',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-51',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-52',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-53',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-54',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-55',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-56',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-57',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-58',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-59',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-60',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-61',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-62',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-63',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-64',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-65',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-66',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 18432)])),
#              ('BatchNorm2d-67',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 512)])),
#              ('ReLU-68',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 256, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-69',
#               OrderedDict([('input_shape', [-1, 256, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 131072)])),
#              ('BatchNorm2d-70',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-71',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-72',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 262144)])),
#              ('BatchNorm2d-73',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-74',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 38, 38]),
#                            ('nb_params', 0)])),
#              ('Conv2d-75',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-76',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-77',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-78',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-79',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('Conv2d-80',
#               OrderedDict([('input_shape', [-1, 512, 38, 38]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-81',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-82',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-83',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-84',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-85',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-86',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-87',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-88',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-89',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-90',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-91',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-92',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-93',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-94',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-95',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-96',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-97',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-98',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-99',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-100',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-101',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-102',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-103',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-104',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-105',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-106',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-107',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-108',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-109',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-110',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-111',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-112',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-113',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-114',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-115',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-116',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-117',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-118',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-119',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-120',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-121',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-122',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 73728)])),
#              ('BatchNorm2d-123',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('ReLU-124',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 512, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-125',
#               OrderedDict([('input_shape', [-1, 512, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 524288)])),
#              ('BatchNorm2d-126',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-127',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-128',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 1048576)])),
#              ('BatchNorm2d-129',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-130',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 19, 19]),
#                            ('nb_params', 0)])),
#              ('Conv2d-131',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-132',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-133',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-134',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-135',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('Conv2d-136',
#               OrderedDict([('input_shape', [-1, 1024, 19, 19]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-137',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-138',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-139',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-140',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-141',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-142',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-143',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-144',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-145',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-146',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-147',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-148',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-149',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-150',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-151',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 294912)])),
#              ('BatchNorm2d-152',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2048)])),
#              ('ReLU-153',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 1024, 10, 10]),
#                            ('nb_params', 0)])),
#              ('Conv2d-154',
#               OrderedDict([('input_shape', [-1, 1024, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 2097152)])),
#              ('BatchNorm2d-155',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('trainable', True),
#                            ('nb_params', 4096)])),
#              ('ReLU-156',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 10, 10]),
#                            ('nb_params', 0)])),
#              ('AdaptiveMaxPool2d-157',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveAvgPool2d-158',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 2048, 1, 1]),
#                            ('nb_params', 0)])),
#              ('AdaptiveConcatPool2d-159',
#               OrderedDict([('input_shape', [-1, 2048, 10, 10]),
#                            ('output_shape', [-1, 4096, 1, 1]),
#                            ('nb_params', 0)])),
#              ('Flatten-160',
#               OrderedDict([('input_shape', [-1, 4096, 1, 1]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-161',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('trainable', True),
#                            ('nb_params', 8192)])),
#              ('Dropout-162',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 4096]),
#                            ('nb_params', 0)])),
#              ('Linear-163',
#               OrderedDict([('input_shape', [-1, 4096]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 2097664)])),
#              ('ReLU-164',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('BatchNorm1d-165',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('trainable', True),
#                            ('nb_params', 1024)])),
#              ('Dropout-166',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 512]),
#                            ('nb_params', 0)])),
#              ('Linear-167',
#               OrderedDict([('input_shape', [-1, 512]),
#                            ('output_shape', [-1, 2]),
#                            ('trainable', True),
#                            ('nb_params', 1026)])),
#              ('LogSoftmax-168',
#               OrderedDict([('input_shape', [-1, 2]),
#                            ('output_shape', [-1, 2]),
#                            ('nb_params', 0)]))])
