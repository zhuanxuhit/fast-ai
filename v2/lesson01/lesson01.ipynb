# %% [markdown]
# ## 深度学习实战第一课：猫狗大战

# %%
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# This file contains all the main external libs we'll use
from fastai.imports import *

# %%
from fastai.transforms import *
from fastai.conv_learner import *
from fastai.model import *
from fastai.dataset import *
from fastai.sgdr import *
from fastai.plots import *

# %%
PATH = "data/dogscats/"

# %%
sz=224

# %% [markdown]
# 先大概浏览下图片

# %%
# !ls {PATH}
# Out:
# models	sample	test1  tmp  train  valid

# %%
# !ls {PATH}valid
# Out:
# cats  dogs

# %%
files = !ls {PATH}valid/cats | head
files
# Out:
# ['cat.10016.jpg',
#  'cat.1001.jpg',
#  'cat.10026.jpg',
#  'cat.10048.jpg',
#  'cat.10050.jpg',
#  'cat.10064.jpg',
#  'cat.10071.jpg',
#  'cat.10091.jpg',
#  'cat.10103.jpg',
#  'cat.10104.jpg']

# %%
img = plt.imread(f'{PATH}valid/cats/{files[0]}')
plt.imshow(img);

# %%
img.shape
# Out:
# (198, 179, 3)

# %%
img[:4,:4]
# Out:
# array([[[ 29,  20,  23],
#         [ 31,  22,  25],
#         [ 34,  25,  28],
#         [ 37,  28,  31]],
#
#        [[ 60,  51,  54],
#         [ 58,  49,  52],
#         [ 56,  47,  50],
#         [ 55,  46,  49]],
#
#        [[ 93,  84,  87],
#         [ 89,  80,  83],
#         [ 85,  76,  79],
#         [ 81,  72,  75]],
#
#        [[104,  95,  98],
#         [103,  94,  97],
#         [102,  93,  96],
#         [102,  93,  96]]], dtype=uint8)

# %% [markdown]
# 第一个模型：resnet34 ，2015 ImageNet 大赛冠军

# %%
arch=resnet34
data = ImageClassifierData.from_paths(PATH, tfms=tfms_from_model(arch, sz))
learn = ConvLearner.pretrained(arch, data, precompute=True)
learn.fit(0.01, 3)
# Out:
# 100%|██████████| 360/360 [01:08<00:00,  5.28it/s]
# 100%|██████████| 32/32 [00:04<00:00,  6.44it/s]
# HBox(children=(IntProgress(value=0, description='Epoch', max=3), HTML(value='')))
# epoch      trn_loss   val_loss   accuracy
#     0      0.054026   0.025939   0.990234
#     1      0.037777   0.025945   0.989258
#     2      0.036444   0.023617   0.991211
# [0.023617273, 0.9912109375]
